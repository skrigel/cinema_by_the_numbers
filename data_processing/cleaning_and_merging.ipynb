# %%
# !pip install sovai
# !pip install uv && uv pip install sovai['full'] --system > output.log 2>&1
# Out:
# Collecting sovai
#   Downloading sovai-0.2.77-py3-none-any.whl.metadata (3.8 kB)
# Collecting aiobotocore==2.21.1 (from sovai)
#   Downloading aiobotocore-2.21.1-py3-none-any.whl.metadata (24 kB)
# Collecting boto3==1.37.1 (from sovai)
#   Downloading boto3-1.37.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore==1.37.1 (from sovai)
#   Downloading botocore-1.37.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting brotli<2.0.0,>=1.1.0 (from sovai)
#   Downloading brotli-1.2.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.1 kB)
# Collecting edgar-tool>=1.3.3 (from sovai)
#   Downloading edgar_tool-2.1.2-py3-none-any.whl.metadata (20 kB)
# Collecting fastapi-cache>=0.1.0 (from sovai)
#   Downloading fastapi-cache-0.1.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fastapi-cache2>=0.2.1 (from fastapi-cache2[redis]>=0.2.1->sovai)
#   Downloading fastapi_cache2-0.2.2-py3-none-any.whl.metadata (8.8 kB)
# Collecting fsspec==2024.10.0 (from sovai)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting gcsfs==2024.10.0 (from sovai)
#   Downloading gcsfs-2024.10.0-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: joblib>=1.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from sovai) (1.5.2)
# Collecting kaleido<2.0.0,>=1.1.0 (from sovai)
#   Downloading kaleido-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting networkx>=3.3 (from sovai)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.20 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from sovai) (1.26.4)
# Requirement already satisfied: pandas>=1.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from sovai) (2.1.1)
# Collecting polars>=1.2 (from sovai)
#   Downloading polars-1.35.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyarrow>=5.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from sovai) (21.0.0)
# Requirement already satisfied: python-dateutil>=2.8 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from sovai) (2.9.0.post0)
# Requirement already satisfied: python-dotenv>=0.10 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from sovai) (1.0.0)
# Collecting pyvis>=0.3.2 (from sovai)
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: rapidfuzz>=3.9.7 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from sovai) (3.13.0)
# Requirement already satisfied: requests>=2.20 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from sovai) (2.32.2)
# Collecting s3fs==2024.10.0 (from sovai)
#   Downloading s3fs-2024.10.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting s3transfer==0.11.3 (from sovai)
#   Downloading s3transfer-0.11.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: seaborn>=0.13.2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from sovai) (0.13.2)
# Collecting skfolio<0.10.0,>=0.9.0 (from sovai)
#   Downloading skfolio-0.9.1-py3-none-any.whl.metadata (22 kB)
# Collecting tqdm<5.0.0,>=4.67.1 (from sovai)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting yachalk>=0.1.6 (from sovai)
#   Downloading yachalk-0.1.8-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from aiobotocore==2.21.1->sovai) (3.11.18)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore==2.21.1->sovai)
#   Downloading aioitertools-0.13.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore==2.21.1->sovai)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from aiobotocore==2.21.1->sovai) (6.4.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from aiobotocore==2.21.1->sovai) (1.17.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from botocore==1.37.1->sovai) (2.2.2)
# Requirement already satisfied: decorator>4.1.2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from gcsfs==2024.10.0->sovai) (5.2.1)
# Requirement already satisfied: google-auth>=1.2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from gcsfs==2024.10.0->sovai) (2.29.0)
# Collecting google-auth-oauthlib (from gcsfs==2024.10.0->sovai)
#   Downloading google_auth_oauthlib-1.2.3-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-cloud-storage (from gcsfs==2024.10.0->sovai)
#   Downloading google_cloud_storage-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.21.1->sovai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.21.1->sovai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.21.1->sovai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.21.1->sovai) (1.6.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.21.1->sovai) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.9.2->aiobotocore==2.21.1->sovai) (1.20.0)
# Collecting choreographer>=1.1.1 (from kaleido<2.0.0,>=1.1.0->sovai)
#   Downloading choreographer-1.2.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting logistro>=1.0.8 (from kaleido<2.0.0,>=1.1.0->sovai)
#   Downloading logistro-2.0.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: orjson>=3.10.15 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from kaleido<2.0.0,>=1.1.0->sovai) (3.10.18)
# Requirement already satisfied: packaging in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from kaleido<2.0.0,>=1.1.0->sovai) (25.0)
# Collecting pytest-timeout>=2.4.0 (from kaleido<2.0.0,>=1.1.0->sovai)
#   Downloading pytest_timeout-2.4.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six>=1.5 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8->sovai) (1.17.0)
# Requirement already satisfied: scipy>=1.15.2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from skfolio<0.10.0,>=0.9.0->sovai) (1.15.3)
# Collecting cvxpy-base>=1.5.0 (from skfolio<0.10.0,>=0.9.0->sovai)
#   Downloading cvxpy_base-1.7.3-cp312-cp312-macosx_10_13_x86_64.whl.metadata (9.4 kB)
# Collecting clarabel>=0.9.0 (from skfolio<0.10.0,>=0.9.0->sovai)
#   Downloading clarabel-0.11.1-cp39-abi3-macosx_10_12_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: scikit-learn>=1.6.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from skfolio<0.10.0,>=0.9.0->sovai) (1.7.2)
# Collecting plotly>=5.22.0 (from skfolio<0.10.0,>=0.9.0->sovai)
#   Downloading plotly-6.4.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: idna>=2.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4.0.0,>=3.9.2->aiobotocore==2.21.1->sovai) (3.7)
# Collecting simplejson>=3.19.3 (from choreographer>=1.1.1->kaleido<2.0.0,>=1.1.0->sovai)
#   Downloading simplejson-3.20.2-cp312-cp312-macosx_10_9_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: cffi in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from clarabel>=0.9.0->skfolio<0.10.0,>=0.9.0->sovai) (1.17.1)
# Requirement already satisfied: click<8.2.0,>=8.1.7 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from edgar-tool>=1.3.3->sovai) (8.1.7)
# Collecting jsonlines<5.0,>=4.0 (from edgar-tool>=1.3.3->sovai)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.5 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from edgar-tool>=1.3.3->sovai) (2.11.7)
# Requirement already satisfied: pytest<9.0.0,>=8.2.2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from edgar-tool>=1.3.3->sovai) (8.4.1)
# Requirement already satisfied: tenacity<9.0,>=8.2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from edgar-tool>=1.3.3->sovai) (8.5.0)
# Collecting typer<0.13.0,>=0.12.5 (from edgar-tool>=1.3.3->sovai)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Collecting xmltodict<0.14,>=0.13 (from edgar-tool>=1.3.3->sovai)
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.10.5->edgar-tool>=1.3.3->sovai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.10.5->edgar-tool>=1.3.3->sovai) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.10.5->edgar-tool>=1.3.3->sovai) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.10.5->edgar-tool>=1.3.3->sovai) (0.4.1)
# Requirement already satisfied: iniconfig>=1 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from pytest<9.0.0,>=8.2.2->edgar-tool>=1.3.3->sovai) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from pytest<9.0.0,>=8.2.2->edgar-tool>=1.3.3->sovai) (1.5.0)
# Requirement already satisfied: pygments>=2.7.2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from pytest<9.0.0,>=8.2.2->edgar-tool>=1.3.3->sovai) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from requests>=2.20->sovai) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from requests>=2.20->sovai) (2025.1.31)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from typer<0.13.0,>=0.12.5->edgar-tool>=1.3.3->sovai) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from typer<0.13.0,>=0.12.5->edgar-tool>=1.3.3->sovai) (13.9.4)
# Collecting aioredis==1.3.1 (from fastapi-cache>=0.1.0->sovai)
#   Downloading aioredis-1.3.1-py3-none-any.whl.metadata (22 kB)
# Collecting async-timeout (from aioredis==1.3.1->fastapi-cache>=0.1.0->sovai)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting hiredis (from aioredis==1.3.1->fastapi-cache>=0.1.0->sovai)
#   Downloading hiredis-3.3.0-cp312-cp312-macosx_10_15_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: fastapi in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from fastapi-cache2>=0.2.1->fastapi-cache2[redis]>=0.2.1->sovai) (0.115.12)
# Collecting pendulum<4.0.0,>=3.0.0 (from fastapi-cache2>=0.2.1->fastapi-cache2[redis]>=0.2.1->sovai)
#   Downloading pendulum-3.1.0-cp312-cp312-macosx_10_12_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: uvicorn in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from fastapi-cache2>=0.2.1->fastapi-cache2[redis]>=0.2.1->sovai) (0.34.2)
# Requirement already satisfied: tzdata>=2020.1 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from pendulum<4.0.0,>=3.0.0->fastapi-cache2>=0.2.1->fastapi-cache2[redis]>=0.2.1->sovai) (2025.2)
# Collecting redis<5.0.0,>=4.2.0rc1 (from fastapi-cache2[redis]>=0.2.1->sovai)
#   Downloading redis-4.6.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from google-auth>=1.2->gcsfs==2024.10.0->sovai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from google-auth>=1.2->gcsfs==2024.10.0->sovai) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from google-auth>=1.2->gcsfs==2024.10.0->sovai) (4.9)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=1.2->gcsfs==2024.10.0->sovai) (0.6.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from pandas>=1.0->sovai) (2025.2)
# Collecting narwhals>=1.15.1 (from plotly>=5.22.0->skfolio<0.10.0,>=0.9.0->sovai)
#   Downloading narwhals-2.11.0-py3-none-any.whl.metadata (11 kB)
# Collecting polars-runtime-32==1.35.2 (from polars>=1.2->sovai)
#   Downloading polars_runtime_32-1.35.2-cp39-abi3-macosx_10_12_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: ipython>=5.3.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from pyvis>=0.3.2->sovai) (9.0.2)
# Requirement already satisfied: jinja2>=2.9.6 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from pyvis>=0.3.2->sovai) (3.1.5)
# Collecting jsonpickle>=1.4.1 (from pyvis>=0.3.2->sovai)
#   Downloading jsonpickle-4.1.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: ipython-pygments-lexers in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->sovai) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->sovai) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->sovai) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->sovai) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->sovai) (3.0.50)
# Requirement already satisfied: stack_data in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->sovai) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->sovai) (5.14.3)
# Requirement already satisfied: wcwidth in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->sovai) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->sovai) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from jinja2>=2.9.6->pyvis>=0.3.2->sovai) (2.1.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->sovai) (0.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from rich>=10.11.0->typer<0.13.0,>=0.12.5->edgar-tool>=1.3.3->sovai) (2.2.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.13.0,>=0.12.5->edgar-tool>=1.3.3->sovai) (0.1.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from scikit-learn>=1.6.0->skfolio<0.10.0,>=0.9.0->sovai) (3.6.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from seaborn>=0.13.2->sovai) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn>=0.13.2->sovai) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn>=0.13.2->sovai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn>=0.13.2->sovai) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn>=0.13.2->sovai) (1.4.8)
# Requirement already satisfied: pillow>=8 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn>=0.13.2->sovai) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn>=0.13.2->sovai) (3.1.2)
# Requirement already satisfied: setuptools in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from yachalk>=0.1.6->sovai) (75.8.0)
# Requirement already satisfied: importlib-resources in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from yachalk>=0.1.6->sovai) (6.5.2)
# Requirement already satisfied: pycparser in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from cffi->clarabel>=0.9.0->skfolio<0.10.0,>=0.9.0->sovai) (2.21)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from fastapi->fastapi-cache2>=0.2.1->fastapi-cache2[redis]>=0.2.1->sovai) (0.46.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from starlette<0.47.0,>=0.40.0->fastapi->fastapi-cache2>=0.2.1->fastapi-cache2[redis]>=0.2.1->sovai) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi->fastapi-cache2>=0.2.1->fastapi-cache2[redis]>=0.2.1->sovai) (1.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from google-auth-oauthlib->gcsfs==2024.10.0->sovai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs==2024.10.0->sovai) (3.2.2)
# Collecting google-api-core<3.0.0,>=2.27.0 (from google-cloud-storage->gcsfs==2024.10.0->sovai)
#   Downloading google_api_core-2.28.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting google-cloud-core<3.0.0,>=2.4.2 (from google-cloud-storage->gcsfs==2024.10.0->sovai)
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage->gcsfs==2024.10.0->sovai)
#   Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage->gcsfs==2024.10.0->sovai)
#   Downloading google_crc32c-1.7.1-cp312-cp312-macosx_12_0_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs==2024.10.0->sovai) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs==2024.10.0->sovai) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs==2024.10.0->sovai) (1.23.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->sovai) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->sovai) (3.0.0)
# Requirement already satisfied: pure_eval in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from stack_data->ipython>=5.3.0->pyvis>=0.3.2->sovai) (0.2.3)
# Requirement already satisfied: h11>=0.8 in /Users/sashakrigel/miniconda3/lib/python3.12/site-packages (from uvicorn->fastapi-cache2>=0.2.1->fastapi-cache2[redis]>=0.2.1->sovai) (0.14.0)
# Downloading sovai-0.2.77-py3-none-any.whl (368 kB)
# Downloading aiobotocore-2.21.1-py3-none-any.whl (78 kB)
# Downloading botocore-1.37.1-py3-none-any.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 18.3 MB/s eta 0:00:00a 0:00:01
# Downloading boto3-1.37.1-py3-none-any.whl (139 kB)
# Downloading s3transfer-0.11.3-py3-none-any.whl (84 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading gcsfs-2024.10.0-py2.py3-none-any.whl (34 kB)
# Downloading s3fs-2024.10.0-py3-none-any.whl (29 kB)
# Downloading aioitertools-0.13.0-py3-none-any.whl (24 kB)
# Downloading brotli-1.2.0-cp312-cp312-macosx_10_13_x86_64.whl (444 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading kaleido-1.2.0-py3-none-any.whl (68 kB)
# Downloading skfolio-0.9.1-py3-none-any.whl (816 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 816.5/816.5 kB 14.4 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading choreographer-1.2.1-py3-none-any.whl (49 kB)
# Downloading clarabel-0.11.1-cp39-abi3-macosx_10_12_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.2 MB/s eta 0:00:00
# Downloading cvxpy_base-1.7.3-cp312-cp312-macosx_10_13_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.5 MB/s eta 0:00:00
# Downloading edgar_tool-2.1.2-py3-none-any.whl (64 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
# Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Downloading aioredis-1.3.1-py3-none-any.whl (65 kB)
# Downloading fastapi_cache2-0.2.2-py3-none-any.whl (25 kB)
# Downloading pendulum-3.1.0-cp312-cp312-macosx_10_12_x86_64.whl (336 kB)
# Downloading redis-4.6.0-py3-none-any.whl (241 kB)
# Downloading logistro-2.0.1-py3-none-any.whl (8.6 kB)
# Downloading networkx-3.5-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 16.3 MB/s eta 0:00:00
# Downloading plotly-6.4.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 19.4 MB/s eta 0:00:00a 0:00:01
# Downloading narwhals-2.11.0-py3-none-any.whl (423 kB)
# Downloading polars-1.35.2-py3-none-any.whl (783 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 783.6/783.6 kB 17.3 MB/s eta 0:00:00
# Downloading polars_runtime_32-1.35.2-cp39-abi3-macosx_10_12_x86_64.whl (40.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 20.0 MB/s eta 0:00:00a 0:00:01
# Downloading pytest_timeout-2.4.0-py3-none-any.whl (14 kB)
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 11.7 MB/s eta 0:00:00
# Downloading jsonpickle-4.1.1-py3-none-any.whl (47 kB)
# Downloading simplejson-3.20.2-cp312-cp312-macosx_10_9_x86_64.whl (75 kB)
# Downloading yachalk-0.1.8-py3-none-any.whl (13 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading google_auth_oauthlib-1.2.3-py3-none-any.whl (19 kB)
# Downloading google_cloud_storage-3.5.0-py3-none-any.whl (289 kB)
# Downloading google_api_core-2.28.1-py3-none-any.whl (173 kB)
# Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.7.1-cp312-cp312-macosx_12_0_x86_64.whl (30 kB)
# Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
# Downloading hiredis-3.3.0-cp312-cp312-macosx_10_15_x86_64.whl (46 kB)
# Building wheels for collected packages: fastapi-cache
#   DEPRECATION: Building 'fastapi-cache' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'fastapi-cache'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for fastapi-cache (setup.py) ... done
#   Created wheel for fastapi-cache: filename=fastapi_cache-0.1.0-py3-none-any.whl size=6399 sha256=ee01eda9a02d6ac3059349f1395e6a8b4847dd15a3764b1b7ea1a0614fc14d41
#   Stored in directory: /Users/sashakrigel/Library/Caches/pip/wheels/ce/e0/7a/6db038d03f6653c9b2adc7420050f160d7219c3ead4dbf119a
# Successfully built fastapi-cache
# Installing collected packages: brotli, yachalk, xmltodict, tqdm, simplejson, redis, polars-runtime-32, networkx, narwhals, logistro, jsonpickle, jsonlines, jmespath, hiredis, google-crc32c, fsspec, async-timeout, aioitertools, pytest-timeout, polars, plotly, pendulum, google-resumable-media, cvxpy-base, clarabel, choreographer, botocore, aioredis, typer, skfolio, s3transfer, pyvis, kaleido, google-auth-oauthlib, google-api-core, fastapi-cache, aiobotocore, s3fs, google-cloud-core, fastapi-cache2, edgar-tool, boto3, google-cloud-storage, gcsfs, sovai
#   Attempting uninstall: brotli
#     Found existing installation: Brotli 1.0.9
#     Uninstalling Brotli-1.0.9:
#       Successfully uninstalled Brotli-1.0.9━━━━━  0/45 [brotli]
#   Attempting uninstall: tqdm━━━━━━━━━━━━━━━━  0/45 [brotli]
#     Found existing installation: tqdm 4.66.4  0/45 [brotli]
#     Uninstalling tqdm-4.66.4:━━━━━━━━━━━━━━━  0/45 [brotli]
#       Successfully uninstalled tqdm-4.66.4━━  0/45 [brotli]
#   Attempting uninstall: fsspec━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/45 [narwhals]ntime-32]
#     Found existing installation: fsspec 2025.3.2━━━━━━━━━━━━━━  8/45 [narwhals]
#     Uninstalling fsspec-2025.3.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  8/45 [narwhals]
#       Successfully uninstalled fsspec-2025.3.2━━━━━━━━━━━━━━━━  8/45 [narwhals]
#   Attempting uninstall: typer━━╺━━━━━━━━━━━━━━━━ 26/45 [botocore]e]mable-media]
#     Found existing installation: typer 0.15.3m━━━━━━━━━━━━━━━━ 26/45 [botocore]
#     Uninstalling typer-0.15.3:m╺━━━━━━━━━━━━━━━━ 26/45 [botocore]
#       Successfully uninstalled typer-0.15.390m━━━━━━━━━━━━━━━━ 26/45 [botocore]
#   Attempting uninstall: google-api-core91m╸━━━━━━━━━━━━━━ 29/45 [skfolio]
#     Found existing installation: google-api-core 2.19.0━━━━━━━ 29/45 [skfolio]
#     Uninstalling google-api-core-2.19.0:━━━━━━━━━━━━━━ 29/45 [skfolio]
#       Successfully uninstalled google-api-core-2.19.0━━━━━━━━━ 29/45 [skfolio]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45/45 [sovai]m [sovai]m [google-cloud-storage]
# Successfully installed aiobotocore-2.21.1 aioitertools-0.13.0 aioredis-1.3.1 async-timeout-5.0.1 boto3-1.37.1 botocore-1.37.1 brotli-1.2.0 choreographer-1.2.1 clarabel-0.11.1 cvxpy-base-1.7.3 edgar-tool-2.1.2 fastapi-cache-0.1.0 fastapi-cache2-0.2.2 fsspec-2024.10.0 gcsfs-2024.10.0 google-api-core-2.28.1 google-auth-oauthlib-1.2.3 google-cloud-core-2.5.0 google-cloud-storage-3.5.0 google-crc32c-1.7.1 google-resumable-media-2.7.2 hiredis-3.3.0 jmespath-1.0.1 jsonlines-4.0.0 jsonpickle-4.1.1 kaleido-1.2.0 logistro-2.0.1 narwhals-2.11.0 networkx-3.5 pendulum-3.1.0 plotly-6.4.0 polars-1.35.2 polars-runtime-32-1.35.2 pytest-timeout-2.4.0 pyvis-0.3.2 redis-4.6.0 s3fs-2024.10.0 s3transfer-0.11.3 simplejson-3.20.2 skfolio-0.9.1 sovai-0.2.77 tqdm-4.67.1 typer-0.12.5 xmltodict-0.13.0 yachalk-0.1.8
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Collecting uv
#   Downloading uv-0.9.9-py3-none-macosx_10_12_x86_64.whl.metadata (11 kB)
# Downloading uv-0.9.9-py3-none-macosx_10_12_x86_64.whl (19.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.6/19.6 MB 24.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: uv
# Successfully installed uv-0.9.9
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# zsh:1: no matches found: sovai[full]

# %%
import sovai as sov
import pandas as pd
import os
# Out:
# Downloading https://storage.googleapis.com/sovai-public/accounting/tickers_transformed.parq to data/tickers.parq
# Downloading https://storage.googleapis.com/sovai-public/sovai-master/output/df_codes.parquet to data/codes.parq

# %% [markdown]
# # Historical + Current Box Office Data
#
# Sourced from sovai - includes film titles, distributers, total gross and approximate gross per theatre, etc.

# %%
sov_token = os.getenv("SOV_API_KEY")
sov.token_auth(token=sov_token)

# %%
df_movies = sov.data("movies/boxoffice")

# %%
sov_df = df_movies.reset_index().copy()
# Extract the year from the 'date' column
sov_df = sov_df.dropna(subset=["date"])
sov_df['year'] = sov_df['date'].dt.year
sov_df = sov_df.drop_duplicates()
sov_df.sort_values(by='year', ascending=False)
# Out:
#        ticker       date                       title   distributor   gross  \
# 236222    WBD 2025-10-30    One Battle After Another  Warner Bros.  188951
# 236220    WBD 2025-10-29    One Battle After Another  Warner Bros.  203608
# 236229    WBD 2025-11-02   The Conjuring: Last Rites  Warner Bros.  105000
# 236211    WBD 2025-10-26   The Conjuring: Last Rites  Warner Bros.  180000
# 236212    WBD 2025-10-26    One Battle After Another  Warner Bros.  740000
# ...       ...        ...                         ...           ...     ...
# 68938   LGF.A 1997-11-07                 Eve's Bayou       Trimark  960000
# 68937   LGF.A 1997-08-24  Dirty Dancing (1987) (Re-…       Vestron   42498
# 68936   LGF.A 1997-08-23  Dirty Dancing (1987) (Re-…       Vestron   59257
# 68933   LGF.A 1997-07-30            Box of Moonlight       Trimark    1537
# 68932   LGF.A 1997-07-29            Box of Moonlight       Trimark    1893
#
#         percent_yd  percent_lw  theaters  per_theater  total_gross  \
# 236222      -0.070      -0.460  1473.000      128.000     66607827
# 236220      -0.290      -0.520  1473.000      138.000     66418876
# 236229      -0.320      -0.410   542.000      194.000    177403000
# 236211      -0.460      -0.570   961.000      187.000    176741000
# 236212      -0.210      -0.270  1473.000      502.000     65786000
# ...            ...         ...       ...          ...          ...
# 68938        0.000       0.000   659.000     1457.000       960000
# 68937       -0.280       0.000    54.000      787.000     63608760
# 68936       -0.020       0.000    54.000     1097.000     63566262
# 68933       -0.190       0.000     1.000     1537.000        18862
# 68932       -0.150       0.000     1.000     1893.000        17325
#
#         days_in_release                   parent company  \
# 236222               35  Warner Bros. Entertainment Inc.
# 236220               34  Warner Bros. Entertainment Inc.
# 236229               59  Warner Bros. Entertainment Inc.
# 236211               52  Warner Bros. Entertainment Inc.
# 236212               31  Warner Bros. Entertainment Inc.
# ...                 ...                              ...
# 68938                 1                        Lionsgate
# 68937              3657                        Lionsgate
# 68936              3656                        Lionsgate
# 68933                 6                        Lionsgate
# 68932                 5                        Lionsgate
#
#                                distributor address  \
# 236222  4000 Warner Blvd., Burbank, California, US
# 236220  4000 Warner Blvd., Burbank, California, US
# 236229  4000 Warner Blvd., Burbank, California, US
# 236211  4000 Warner Blvd., Burbank, California, US
# 236212  4000 Warner Blvd., Burbank, California, US
# ...                                            ...
# 68938      Santa Monica, California, United States
# 68937             Chicago, Illinois, United States
# 68936             Chicago, Illinois, United States
# 68933      Santa Monica, California, United States
# 68932      Santa Monica, California, United States
#
#                  distributorwebsite release_date  year
# 236222  https://www.warnerbros.com/   2025-09-25  2025
# 236220  https://www.warnerbros.com/   2025-09-25  2025
# 236229  https://www.warnerbros.com/   2025-09-04  2025
# 236211  https://www.warnerbros.com/   2025-09-04  2025
# 236212  https://www.warnerbros.com/   2025-09-25  2025
# ...                             ...          ...   ...
# 68938                          None   1997-11-06  1997
# 68937                          None   1987-08-20  1997
# 68936                          None   1987-08-20  1997
# 68933                          None   1997-07-24  1997
# 68932                          None   1997-07-24  1997
#
# [236244 rows x 16 columns]

# %%
print(f"Unique titles: {sov_df['title'].nunique()}")
print(f"Total rows: {len(sov_df)}")
# Out:
# Unique titles: 5996
# Total rows: 236244

# %%
def normalize_title(s):
    s = s.astype(str).str.lower().str.strip()
    return s

# %% [markdown]
# # Film Ratings + Other Film Metadata
#
# Sourced from TMDB (the movie database)
#
# Includes aggregate runtimes, popularity ratings, descriptions of movies, number of raters, also includes revenue etc.
#
# [Movie details for a given movie id](https://developer.themoviedb.org/reference/movie-details)
#
#
# Here is the drive folder with the bulk movie id data:
# [download tmdb_movie_ids.csv](https://drive.google.com/file/d/1gOMNDu7MLIriftb3audXMP0UEmZAiHQt/view?usp=sharing)

# %%
import requests
import json

# %%
RAW_DATA_PATH = "raw"

# %%
tmdb_df = pd.read_csv(f"{RAW_DATA_PATH}/tmdb_movie_ids.csv")
print(tmdb_df.columns)
# Out:
# Index(['adult', 'id', 'original_title', 'popularity', 'video'], dtype='object')

# %%
tmdb_df.sort_values(by='popularity', ascending=False)
# Out:
#          adult       id                   original_title  popularity  video
# 811727   False  1156594                    Culpa nuestra     532.152  False
# 1073852  False  1511789  Captain Hook - The Cursed Tides     340.513  False
# 534839   False   755898                War of the Worlds     317.302  False
# 907504   False  1280450                      Stolen Girl     304.141  False
# 926600   False  1305717                  Hunting Grounds     300.462  False
# ...        ...      ...                              ...         ...    ...
# 781645   False  1114005  Tio år på en minut - 2000-talet       0.000  False
# 781637   False  1113990             The Wheel'd Universe       0.000  False
# 477584   False   677812           Revolver cachas de oro       0.000  False
# 477583   False   677811                  Perros de pelea       0.000  False
# 273367   False   410084   El color de la tierra: Chiapas       0.000  False
#
# [1119418 rows x 5 columns]

# %% [markdown]
# # DATA CLEANING TO MERGE
#
#
#
# 1.   Normalizing Titles: Movie titles often contain variations in capitalization, spacing, punctuation, etc., which can prevent matching across different datasets. To address this, we normalize all titles to the same format, creating a consistent key for merging called title_key.
# 2. SOVAI Data Cleaning: This dataset contains historical performance data, including gross revenue, number of theaters, and release dates. To clean up this data:
#
# *   Duplicate entries are removed, keeping the row with the latest release data and highest revenue
# *   Numeric columns (gross, total_gross, theaters) are converted to numeric types
# * Rows missing critical data (title_key, gross, date) are dropped
# 3. TMDB Data Cleaning: This dataset contains basic metadata including ID, title, popularity – which we keep and normalize as needed, also converting popularity to a numeric value
# 4. Merging Datasets: The cleaned datasets are merged on title_key, ensuring that only movies present in both datasets are included and thus also combining data from both sources.
# 5. Feature Engineering/Extraction: Additional features can be derived from the newly created dataset to improve predictive power. One example  includes a flag indicating if the date released is_weekend.

# %%
sov_df['title_key'] = normalize_title(sov_df['title'])
tmdb_df['title_key'] = normalize_title(tmdb_df['original_title'])

# %%
# Clean SOVAI data
# Drop duplicates: keep latest/highest grossing per movie
sov_df = sov_df.sort_values(
    by=['title_key', 'date', 'total_gross', 'theaters'],
    ascending=[True, False, False, False]
)
sov_latest = sov_df.drop_duplicates(subset=['title_key'], keep='first').copy()

# Convert numeric columns
for col in ['gross', 'per_theater', 'theaters', 'total_gross', 'days_in_release']:
    if col in sov_latest.columns:
        sov_latest[col] = pd.to_numeric(sov_latest[col], errors='coerce')

# Drop rows missing critical data
sov_latest = sov_latest.dropna(subset=['title_key', 'gross', 'date'])

# %%
# Clean TMDB CSV (minimal)
# Keep only relevant columns
tmdb_df = tmdb_df[['id', 'original_title', 'popularity', 'title_key']].copy()
tmdb_df['popularity'] = pd.to_numeric(tmdb_df['popularity'], errors='coerce')

# %% [markdown]
# # Merge

# %%
# Merge SOVAI + TMDB

merged_df = pd.merge(
    sov_latest,
    tmdb_df,
    how='inner',  # only keep movies present in both
    on='title_key',
    suffixes=('_sov', '_tmdb')
)

# Feature engineering - Weekday/weekend flag based on SOVAI date
merged_df['weekday'] = merged_df['date'].dt.weekday
merged_df['is_weekend'] = merged_df['weekday'].isin([4,5,6]).astype(int)

n=30
print(merged_df[['title_key', 'date', 'gross', 'popularity', 'is_weekend']].head(n)) #printing first n
# Out:
#               title_key       date   gross  popularity  is_weekend
# 0   10 cloverfield lane 2016-06-02   11414       7.837           0
# 1            100 meters 2025-10-16     313       0.014           0
# 2           102 not out 2018-06-03    2806       3.454           1
# 3           10th & wolf 2006-09-04    1791       3.656           0
# 4             11th hour 2007-09-03   64888       2.311           0
# 5             11th hour 2007-09-03   64888       0.184           0
# 6                    12 2009-05-25     344       2.658           0
# 7                    12 2009-05-25     344       0.205           0
# 8                    12 2009-05-25     344       0.262           0
# 9                    12 2009-05-25     344       1.321           0
# 10                   12 2009-05-25     344       1.701           0
# 11                   12 2009-05-25     344       0.256           0
# 12                   12 2009-05-25     344       0.139           0
# 13                   12 2009-05-25     344       0.305           0
# 14                   12 2009-05-25     344       0.000           0
# 15                   12 2009-05-25     344       1.794           0
# 16                   12 2009-05-25     344       0.153           0
# 17                   12 2009-05-25     344       0.153           0
# 18            12 rounds 2009-05-25    4832       4.832           0
# 19            12 rounds 2009-05-25    4832       0.436           0
# 20            12 rounds 2009-05-25    4832       0.131           0
# 21            12 strong 2018-03-29    4502       6.575           0
# 22       13 going on 30 2004-06-03  115000       9.991           0
# 23                 1408 2007-09-03   38250       7.405           0
# 24           15 minutes 2001-04-05   89000       3.804           0
# 25           15 minutes 2001-04-05   89000       0.014           0
# 26           15 minutes 2001-04-05   89000       0.068           0
# 27           15 minutes 2001-04-05   89000       0.041           0
# 28            16 blocks 2006-03-30  214226       4.003           0
# 29             17 again 2009-08-06    3942       7.457           0

# %%
import pandas as pd
from tabulate import tabulate

# --- SOV.AI SCHEMA ---
schema_sovai = pd.DataFrame({
    "Data Field": sov_latest.columns,
    "Data Type": sov_latest.dtypes.astype(str)
})

print("SOV.AI Dataset Schema:")
print(tabulate(schema_sovai, headers="keys", tablefmt="github"))
print("\n")


# --- TMDB SCHEMA ---
schema_tmdb = pd.DataFrame({
    "Data Field": tmdb_df.columns,
    "Data Type": tmdb_df.dtypes.astype(str)
})

print("TMDB Dataset Schema:")
print(tabulate(schema_tmdb, headers="keys", tablefmt="github"))
print("\n")


# --- MERGED DATASET SCHEMA ---
schema_merged = pd.DataFrame({
    "Data Field": merged_df.columns,
    "Data Type": merged_df.dtypes.astype(str)
})

print("Merged Dataset Schema:")
print(tabulate(schema_merged, headers="keys", tablefmt="github"))
print("\n")


# OPTIONAL: save to CSV files
schema_sovai.to_csv("schema_sovai.csv", index=False)
schema_tmdb.to_csv("schema_tmdb.csv", index=False)
schema_merged.to_csv("schema_merged.csv", index=False)
# Out:
# SOV.AI Dataset Schema:
# |                     | Data Field          | Data Type      |
# |---------------------|---------------------|----------------|
# | ticker              | ticker              | object         |
# | date                | date                | datetime64[ns] |
# | title               | title               | string         |
# | distributor         | distributor         | object         |
# | gross               | gross               | Int64          |
# | percent_yd          | percent_yd          | Float64        |
# | percent_lw          | percent_lw          | Float64        |
# | theaters            | theaters            | Float64        |
# | per_theater         | per_theater         | Float64        |
# | total_gross         | total_gross         | Int64          |
# | days_in_release     | days_in_release     | Int64          |
# | parent company      | parent company      | object         |
# | distributor address | distributor address | object         |
# | distributorwebsite  | distributorwebsite  | object         |
# | release_date        | release_date        | datetime64[ns] |
# | year                | year                | int32          |
# | title_key           | title_key           | object         |
#
#
# TMDB Dataset Schema:
# |                | Data Field     | Data Type   |
# |----------------|----------------|-------------|
# | id             | id             | int64       |
# | original_title | original_title | object      |
# | popularity     | popularity     | float64     |
# | title_key      | title_key      | object      |
#
#
# Merged Dataset Schema:
# |                     | Data Field          | Data Type      |
# |---------------------|---------------------|----------------|
# | ticker              | ticker              | object         |
# | date                | date                | datetime64[ns] |
# | title               | title               | string         |
# | distributor         | distributor         | object         |
# | gross               | gross               | Int64          |
# | percent_yd          | percent_yd          | Float64        |
# | percent_lw          | percent_lw          | Float64        |
# | theaters            | theaters            | Float64        |
# | per_theater         | per_theater         | Float64        |
# | total_gross         | total_gross         | Int64          |
# | days_in_release     | days_in_release     | Int64          |
# | parent company      | parent company      | object         |
# | distributor address | distributor address | object         |
# | distributorwebsite  | distributorwebsite  | object         |
# | release_date        | release_date        | datetime64[ns] |
# | year                | year                | int32          |
# | title_key           | title_key           | object         |
# | id                  | id                  | int64          |
# | original_title      | original_title      | object         |
# | popularity          | popularity          | float64        |
# | weekday             | weekday             | int32          |
# | is_weekend          | is_weekend          | int64          |
