# %%
import pandas as pd
import os

# %% [markdown]
# ## Extract Movie Details from TMDB API

# %%
import json, requests

# %%
tmdb_key = os.getenv("TMDB_API_KEY")

headers = {
    "accept": "application/json",
    "Authorization": f"Bearer {tmdb_key}"
}

# %% [markdown]
# Note that there are a bunch of different endpoints for different sorts of info, meaning we could query by:
#
#
# *   movie_id
# *   genre
# *   what's popular/trending
# *   keywords
# *   release dates...
#
# You get the idea.
#
# View API Reference here: [TMDB API Reference](https://developer.themoviedb.org/reference/getting-started)
#
# Idk exactly what rate limiting looks like, but I don't think we should try to extract details from ALL the ids in the movie id dataset

# %%
movie_url = "https://api.themoviedb.org/3/discover/movie"

details_url = "https://api.themoviedb.org/3/movie/"

# %%
from utils import flatten_movie_data, get_n_most_recent_movies

# %% [markdown]
# ### Flatten movie data recieved from API

# %%
def query_movie_details(movie_id):
  details_payload = requests.get(f"{details_url}{movie_id}", headers=headers).text

  return flatten_movie_data(json.loads(details_payload))

def get_movie_id(df, title):
    row = df[df["original_title"].str.lower() == title.lower()]
    return int(row["id"].values[0]) if not row.empty else None

# %% [markdown]
# ## Collect most recent titles

# %%
n = 50
recent_movies = get_n_most_recent_movies(
    n=n,
    headers=headers,
    verbose=True
)

recent_movies_df = pd.DataFrame(recent_movies)
recent_movies_df.head()
# Out:
# Requesting discover page 1...
# Requesting discover page 2...
# Requesting discover page 3...
#         id     imdb_id               title      original_title  \
# 0  1062722   tt1312221        Frankenstein        Frankenstein
# 1  1242898  tt31227572  Predator: Badlands  Predator: Badlands
# 2  1197137  tt29644189       Black Phone 2       Black Phone 2
# 3  1161617  tt26394837              Code 3              Code 3
# 4   755898  tt13186306   War of the Worlds   War of the Worlds
#
#   original_language release_date    status  \
# 0                en   2025-10-17  Released
# 1                en   2025-11-05  Released
# 2                en   2025-10-15  Released
# 3                en   2025-09-12  Released
# 4                en   2025-07-29  Released
#
#                                             homepage     budget    revenue  \
# 0             https://www.netflix.com/title/81507921  120000000     144496
# 1  https://www.20thcenturystudios.com/movies/pred...  105000000   80000000
# 2                     http://www.blackphonemovie.com   30000000  120233805
# 3   https://auraentertainment.com/aura/titles/code-3          0      12140
# 4  https://www.amazon.com/gp/video/detail/B0DMF7MXKT          0          0
#
#    ...    genre_ids                         genre_names  \
# 0  ...   18, 27, 14              Drama, Horror, Fantasy
# 1  ...  28, 878, 12  Action, Science Fiction, Adventure
# 2  ...       27, 53                    Horror, Thriller
# 3  ...       28, 35                      Action, Comedy
# 4  ...      878, 53           Science Fiction, Thriller
#
#                   production_company_ids  \
# 0                  101082, 10678, 279898
# 1       127928, 840, 1302, 185309, 22213
# 2                3172, 33, 162439, 89115
# 3  144610, 23921, 248202, 248203, 248204
# 4                      33, 109501, 59827
#
#                             production_company_names  \
# 0         Double Dare You, Demilo Films, Bluegrass 7
# 1  20th Century Studios, Lawrence Gordon Producti...
# 2  Blumhouse Productions, Universal Pictures, Cro...
# 3  Wayfarer Studios, Circle of Confusion, Electro...
# 4  Universal Pictures, Bazelevs, Patrick Aiello P...
#
#    production_company_countries  production_country_codes  \
# 0                    US, CA, US                    US, CA
# 1            US, US, US, US, US                        US
# 2                US, US, US, US                        US
# 3                  US, US, , ,                         US
# 4                    US, US, US                        US
#
#            production_country_names       belongs_to_collection  \
# 0  United States of America, Canada                        None
# 1          United States of America         Predator Collection
# 2          United States of America  The Black Phone Collection
# 3          United States of America                        None
# 4          United States of America                        None
#
#   discover_release_date discover_popularity
# 0            2025-10-17           1011.0264
# 1            2025-11-05            336.7196
# 2            2025-10-15            321.3047
# 3            2025-09-12            274.9442
# 4            2025-07-29            251.7910
#
# [5 rows x 29 columns]
